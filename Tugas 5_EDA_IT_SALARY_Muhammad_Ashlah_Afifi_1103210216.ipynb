# %% [markdown]
# <a href="https://colab.research.google.com/github/ashlahafifi/AshlahA/blob/main/Tugas%205_EDA_IT_SALARY_Muhammad_Ashlah_Afifi_1103210216.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama  : Muhammad Ashlah Afifi
# NIM   : 1103210216
# Tugas : EDA IT Salary Dataset Week 5

# %% [markdown]
# MOUNT GDRIVE TO GCOLAB

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# IMPORT LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# READ DATA FROM GDRIVE TO GCOLAB

# %%
# File path
file_path = '/content/drive/MyDrive/Dataset/IT Salary Survey EU  2020.csv'

# Read dataset
df = pd.read_csv(file_path)

# Display the first few rows of the dataframe
df.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %% [markdown]
# SHOW DATA

# %%
df.tail()
# Out:
#                 Timestamp   Age Gender         City  \
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 1248                       Backend Developer                         9
# 1249  Researcher/ Consumer Insights Analyst                         10
# 1250                   IT Operations Manager                        15
# 1251                      Frontend Developer                         7
# 1252                                  DevOps                         2
#
#      Years of experience in Germany Seniority level  \
# 1248                              5          Senior
# 1249                            1.5          Senior
# 1250                              2            Lead
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
numeric_columns = ["Total years of experience",
                    "Years of experience in Germany",
                    "Yearly bonus + stocks in EUR",
                    "Annual bonus+stocks one year ago. Only answer if staying in same country",
                    "Number of vacation days",
                    "Contract duration",
                    "Company size"]

# Display the first five rows of selected columns
print(df.head())
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %% [markdown]
# Change to Numeric

# %%
# Select specific columns
numeric_columns = ["Total years of experience",
                    "Years of experience in Germany",
                    "Yearly bonus + stocks in EUR",
                    "Annual bonus+stocks one year ago. Only answer if staying in same country",
                    "Number of vacation days",
                    "Company size"]

# Convert selected columns to numeric
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Display the first five rows of selected columns
print(df[numeric_columns].head())
# Out:
#    Total years of experience  Years of experience in Germany  \
# 0                        5.0                             3.0
# 1                        7.0                             4.0
# 2                       12.0                             6.0
# 3                        4.0                             1.0
# 4                       17.0                             6.0
#
#    Yearly bonus + stocks in EUR  \
# 0                        5000.0
# 1                           NaN
# 2                      120000.0
# 3                           NaN
# 4                           NaN
#
#    Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 0                                            10000.0
# 1                                             5000.0
# 2                                           100000.0
# 3                                                NaN
# 4                                                NaN
#
#    Number of vacation days  Company size
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age  Total years of experience  Years of experience in Germany  \
# count  1226.000000                1230.000000                     1194.000000
# mean     32.509788                   9.078130                        3.757956
# std       5.663804                  11.901317                        3.656551
# min      20.000000                   0.000000                        0.000000
# 25%      29.000000                   5.000000                        1.000000
# 50%      32.000000                   8.000000                        3.000000
# 75%      35.000000                  12.000000                        5.000000
# max      69.000000                 383.000000                       30.000000
#
#        Yearly brutto salary (without bonus and stocks) in EUR  \
# count                                       1.253000e+03
# mean                                        8.027904e+07
# std                                         2.825061e+09
# ...

# %%
print(df.describe())
# Out:
#                Age  Total years of experience  Years of experience in Germany  \
# count  1226.000000                1230.000000                     1194.000000
# mean     32.509788                   9.078130                        3.757956
# std       5.663804                  11.901317                        3.656551
# min      20.000000                   0.000000                        0.000000
# 25%      29.000000                   5.000000                        1.000000
# 50%      32.000000                   8.000000                        3.000000
# 75%      35.000000                  12.000000                        5.000000
# max      69.000000                 383.000000                       30.000000
#
#        Yearly brutto salary (without bonus and stocks) in EUR  \
# count                                       1.253000e+03
# mean                                        8.027904e+07
# std                                         2.825061e+09
# ...

# %%
# Show Lines they have nulls
rows_with_null = df[df.isnull().any(axis=1)]
print(rows_with_null)
# Out:
#                 Timestamp   Age Gender         City  \
# 0     24/11/2020 11:14:15  26.0   Male       Munich
# 1     24/11/2020 11:14:16  26.0   Male       Berlin
# 2     24/11/2020 11:14:21  29.0   Male       Berlin
# 3     24/11/2020 11:15:24  28.0   Male       Berlin
# 4     24/11/2020 11:15:46  37.0   Male       Berlin
# ...                   ...   ...    ...          ...
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position   Total years of experience  \
# 0                          Software Engineer                        5.0
# 1                          Backend Developer                        7.0
# 2                          Software Engineer                       12.0
# ...

# %%
plt.hist(df['Total years of experience'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Total years of experience')
plt.ylabel('Frequency')
plt.title('Histogram of Total years of experience')
plt.show()

# %%
sns.boxplot(x=df['Years of experience in Germany'])
plt.xlabel('Years of experience in Germany')
plt.title('Boxplot of Years of experience in Germany')
plt.show()

# %%
plt.scatter(df['Total years of experience'], df['Yearly bonus + stocks in EUR'], color='green', alpha=0.5)
plt.xlabel('Total years of experience')
plt.ylabel('Yearly bonus + stocks in EUR')
plt.title('Scatter plot of Total years of experience vs Yearly bonus + stocks in EUR')
plt.show()

# %%
# Calculates correlation between numeric columns
correlation_matrix = df.corr()

# Make heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='magma', fmt=".2f")
plt.title('Heatmap Korelasi Antar Kolom Numerik')
plt.show()
# Out:
# <ipython-input-42-b68e2fe8140b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
